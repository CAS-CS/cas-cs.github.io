# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib as mpl
import matplotlib.pyplot as plt
import os,glob,shutil,gzip

# %%
print(os.getcwd())
file="Jeeves.xlsx"
data=pd.read_excel(file)
data
# Out:
# /home/prateek/Documents/GITHUB/CAS-CS/cas-cs.github.io/lectures/FoML/.PythonCode/ClassDemo
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 0      Rainy   Hot     High  False       No
# 1      Rainy   Hot     High   True       No
# 2   Overcast   Hot     High  False      Yes
# 3      Sunny  Mild     High  False      Yes
# 4      Sunny  Cool   Normal  False      Yes
# 5      Sunny  Cool   Normal   True       No
# 6   Overcast  Cool   Normal   True      Yes
# 7      Rainy  Mild     High  False       No
# 8      Rainy  Cool   Normal  False      Yes
# 9      Sunny  Mild   Normal  False      Yes
# 10     Rainy  Mild   Normal   True      Yes
# 11  Overcast  Mild     High   True      Yes
# 12  Overcast   Hot   Normal  False      Yes
# 13     Sunny  Mild     High   True       No

# %%
list(data.head(0))
# Out:
# ['OUTLOOK', 'Temp', 'Humidity', 'Windy', 'PlayGolf']

# %%
class Entropy:
    def __init__(self,df):
        self.df=df
        self.H=self.EntropyCalc()
    
    def EntropyCalc(self):
        df=self.df
        self.S=list(df.iloc[:, -1].values)
        self.set=list(set(self.S))
        p=[]
        count=[]
        for i,val in enumerate(self.set):
            count.append(self.S.count(val))
            p.append(self.S.count(val)/len(self.S))
        self.count=count
        self.P=np.array(p)
        self.H=np.sum(-1*self.P*np.log2(self.P))
        return self.H

    def __repr__(self):
        print("Input Data Frame")
        print(f"{self.df}\n")

        print(f"There are {len(self.S)} elements in sample space")
        print(f"Sample space: \n{self.S}")
        print(f"Unique values:\t{self.set}")
        print(f"Count of Unique values:\t {self.count}")
        print(f"Probability:\t {self.P}")
        print(f"\nEntropy={self.H}")
        return ''

print(Entropy(data))
main=Entropy(data)
H=main.H
H
# Out:
# Input Data Frame
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 0      Rainy   Hot     High  False       No
# 1      Rainy   Hot     High   True       No
# 2   Overcast   Hot     High  False      Yes
# 3      Sunny  Mild     High  False      Yes
# 4      Sunny  Cool   Normal  False      Yes
# 5      Sunny  Cool   Normal   True       No
# 6   Overcast  Cool   Normal   True      Yes
# 7      Rainy  Mild     High  False       No
# 8      Rainy  Cool   Normal  False      Yes
# 9      Sunny  Mild   Normal  False      Yes
# 10     Rainy  Mild   Normal   True      Yes
# 11  Overcast  Mild     High   True      Yes
# 12  Overcast   Hot   Normal  False      Yes
# 13     Sunny  Mild     High   True       No
#
# There are 14 elements in sample space
# Sample space:
# ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# Unique values:	['No', 'Yes']
# Count of Unique values:	 [5, 9]
# Probability:	 [0.35714286 0.64285714]
#
# Entropy=0.9402859586706311
# 0.9402859586706311

# %%
def Prob(S,event):
    # print(S,event)
    S=list(S)
    event=event

    # print(S,event)
    p=[]
    p.append(S.count(event)/len(S))
    # print(p)
    return p

# S=list(data["OUTLOOK"].values)
# Prob(S,'Sunny')

# %%
Hmain=Entropy(data).H
InformationGain=[]
print(f"Entropy of Complete data set i {Hmain}")
S=list(data.head(0))
for i,col in enumerate(S):
    # print(i,len(list(data.head(0)))-1)
    if i==len(list(data.head(0)))-1:
        break
    elements=list(data[col])
    uElement=set(elements)
    print('\n\n\n=========================')
    print(f"Testing for {col}")
    print('=========================\n')
    print(f"Entries are: {elements}")
    print(f"Unique entries are: {uElement}")
    
    print('\n')
    Imat=[]
    for e in uElement:
        
        print('\n-------------------------------------')
        print(f"Checking for {col} == {e}")
        print('-------------------------------------\n')
        df=data[data[col]==e]
        P=Prob(data[col],e)[0]
        H=Entropy(df).H
        I=P*H
        Imat.append(I)
        print(f"Probability of {col} == {e} is {P}")
        df=df.drop(col,axis=1)
        print(f"Entropy of {col} == {e} is {H}")
        print(f"Information Gain of {col} when {e} is {I}")
        
        
        print('\n')
        print(df)
        print('\n')

    IG=Hmain-np.sum(Imat)
    InformationGain.append(IG)
    print("\n\n\n++++++++++++++++++++++++++++++++++")
    print(f'Information gain of {col} with is {IG}')
    print("++++++++++++++++++++++++++++++++++\n\n")

print("\n\n\n********************************************")
print(f'Information gain MATRIX {S[0:-2]} with is {InformationGain}')
print("********************************************")
# Out:
# Entropy of Complete data set i 0.9402859586706311
#
#
#
# =========================
# Testing for OUTLOOK
# =========================
#
# Entries are: ['Rainy', 'Rainy', 'Overcast', 'Sunny', 'Sunny', 'Sunny', 'Overcast', 'Rainy', 'Rainy', 'Sunny', 'Rainy', 'Overcast', 'Overcast', 'Sunny']
# Unique entries are: {'Rainy', 'Sunny', 'Overcast'}
#
#
#
# -------------------------------------
# Checking for OUTLOOK == Rainy
# -------------------------------------
#
# Probability of OUTLOOK == Rainy is 0.35714285714285715
# Entropy of OUTLOOK == Rainy is 0.9709505944546686
# Information Gain of OUTLOOK when Rainy is 0.3467680694480959
#
#
#     Temp Humidity  Windy PlayGolf
# 0    Hot     High  False       No
# 1    Hot     High   True       No
# 7   Mild     High  False       No
# 8   Cool   Normal  False      Yes
# 10  Mild   Normal   True      Yes
#
#
#
# -------------------------------------
# Checking for OUTLOOK == Sunny
# -------------------------------------
#
# Probability of OUTLOOK == Sunny is 0.35714285714285715
# Entropy of OUTLOOK == Sunny is 0.9709505944546686
# Information Gain of OUTLOOK when Sunny is 0.3467680694480959
#
#
#     Temp Humidity  Windy PlayGolf
# 3   Mild     High  False      Yes
# 4   Cool   Normal  False      Yes
# 5   Cool   Normal   True       No
# 9   Mild   Normal  False      Yes
# 13  Mild     High   True       No
#
#
#
# -------------------------------------
# Checking for OUTLOOK == Overcast
# -------------------------------------
#
# Probability of OUTLOOK == Overcast is 0.2857142857142857
# Entropy of OUTLOOK == Overcast is 0.0
# Information Gain of OUTLOOK when Overcast is 0.0
#
#
#     Temp Humidity  Windy PlayGolf
# 2    Hot     High  False      Yes
# 6   Cool   Normal   True      Yes
# 11  Mild     High   True      Yes
# 12   Hot   Normal  False      Yes
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of OUTLOOK with is 0.24674981977443933
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# =========================
# Testing for Temp
# =========================
#
# Entries are: ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool', 'Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild']
# Unique entries are: {'Mild', 'Cool', 'Hot'}
#
#
#
# -------------------------------------
# Checking for Temp == Mild
# -------------------------------------
#
# Probability of Temp == Mild is 0.42857142857142855
# Entropy of Temp == Mild is 0.9182958340544896
# Information Gain of Temp when Mild is 0.39355535745192405
#
#
#      OUTLOOK Humidity  Windy PlayGolf
# 3      Sunny     High  False      Yes
# 7      Rainy     High  False       No
# 9      Sunny   Normal  False      Yes
# 10     Rainy   Normal   True      Yes
# 11  Overcast     High   True      Yes
# 13     Sunny     High   True       No
#
#
#
# -------------------------------------
# Checking for Temp == Cool
# -------------------------------------
#
# Probability of Temp == Cool is 0.2857142857142857
# Entropy of Temp == Cool is 0.8112781244591328
# Information Gain of Temp when Cool is 0.23179374984546652
#
#
#     OUTLOOK Humidity  Windy PlayGolf
# 4     Sunny   Normal  False      Yes
# 5     Sunny   Normal   True       No
# 6  Overcast   Normal   True      Yes
# 8     Rainy   Normal  False      Yes
#
#
#
# -------------------------------------
# Checking for Temp == Hot
# -------------------------------------
#
# Probability of Temp == Hot is 0.2857142857142857
# Entropy of Temp == Hot is 1.0
# Information Gain of Temp when Hot is 0.2857142857142857
#
#
#      OUTLOOK Humidity  Windy PlayGolf
# 0      Rainy     High  False       No
# 1      Rainy     High   True       No
# 2   Overcast     High  False      Yes
# 12  Overcast   Normal  False      Yes
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Temp with is 0.02922256565895487
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# =========================
# Testing for Humidity
# =========================
#
# Entries are: ['High', 'High', 'High', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'High']
# Unique entries are: {'High', 'Normal'}
#
#
#
# -------------------------------------
# Checking for Humidity == High
# -------------------------------------
#
# Probability of Humidity == High is 0.5
# Entropy of Humidity == High is 0.9852281360342515
# Information Gain of Humidity when High is 0.49261406801712576
#
#
#      OUTLOOK  Temp  Windy PlayGolf
# 0      Rainy   Hot  False       No
# 1      Rainy   Hot   True       No
# 2   Overcast   Hot  False      Yes
# 3      Sunny  Mild  False      Yes
# 7      Rainy  Mild  False       No
# 11  Overcast  Mild   True      Yes
# 13     Sunny  Mild   True       No
#
#
#
# -------------------------------------
# Checking for Humidity == Normal
# -------------------------------------
#
# Probability of Humidity == Normal is 0.5
# Entropy of Humidity == Normal is 0.5916727785823275
# Information Gain of Humidity when Normal is 0.29583638929116374
#
#
#      OUTLOOK  Temp  Windy PlayGolf
# 4      Sunny  Cool  False      Yes
# 5      Sunny  Cool   True       No
# 6   Overcast  Cool   True      Yes
# 8      Rainy  Cool  False      Yes
# 9      Sunny  Mild  False      Yes
# 10     Rainy  Mild   True      Yes
# 12  Overcast   Hot  False      Yes
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Humidity with is 0.15183550136234159
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# =========================
# Testing for Windy
# =========================
#
# Entries are: [False, True, False, False, False, True, True, False, False, False, True, True, False, True]
# Unique entries are: {False, True}
#
#
#
# -------------------------------------
# Checking for Windy == False
# -------------------------------------
#
# Probability of Windy == False is 0.5714285714285714
# Entropy of Windy == False is 0.8112781244591328
# Information Gain of Windy when False is 0.46358749969093305
#
#
#      OUTLOOK  Temp Humidity PlayGolf
# 0      Rainy   Hot     High       No
# 2   Overcast   Hot     High      Yes
# 3      Sunny  Mild     High      Yes
# 4      Sunny  Cool   Normal      Yes
# 7      Rainy  Mild     High       No
# 8      Rainy  Cool   Normal      Yes
# 9      Sunny  Mild   Normal      Yes
# 12  Overcast   Hot   Normal      Yes
#
#
#
# -------------------------------------
# Checking for Windy == True
# -------------------------------------
#
# Probability of Windy == True is 0.42857142857142855
# Entropy of Windy == True is 1.0
# Information Gain of Windy when True is 0.42857142857142855
#
#
#      OUTLOOK  Temp Humidity PlayGolf
# 1      Rainy   Hot     High       No
# 5      Sunny  Cool   Normal       No
# 6   Overcast  Cool   Normal      Yes
# 10     Rainy  Mild   Normal      Yes
# 11  Overcast  Mild     High      Yes
# 13     Sunny  Mild     High       No
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Windy with is 0.04812703040826949
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# ********************************************
# Information gain MATRIX ['OUTLOOK', 'Temp', 'Humidity'] with is [0.24674981977443933, 0.02922256565895487, 0.15183550136234159, 0.04812703040826949]
# ********************************************
