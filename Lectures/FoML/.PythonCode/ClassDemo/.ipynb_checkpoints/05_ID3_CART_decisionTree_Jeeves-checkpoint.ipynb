# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib as mpl
import matplotlib.pyplot as plt
import os,glob,shutil,gzip

# %%
print(os.getcwd())
file="Jeeves.xlsx"
data=pd.read_excel(file)
data
# Out:
# /home/prateek/Documents/GITHUB/CAS-CS/cas-cs.github.io/lectures/FoML/.PythonCode/ClassDemo
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 0      Rainy   Hot     High  False       No
# 1      Rainy   Hot     High   True       No
# 2   Overcast   Hot     High  False      Yes
# 3      Sunny  Mild     High  False      Yes
# 4      Sunny  Cool   Normal  False      Yes
# 5      Sunny  Cool   Normal   True       No
# 6   Overcast  Cool     High   True      Yes
# 7      Rainy  Mild   Normal  False      Yes
# 8      Rainy  Cool   Normal  False      Yes
# 9      Sunny  Mild   Normal  False      Yes
# 10     Rainy  Mild   Normal   True      Yes
# 11  Overcast  Mild     High   True      Yes
# 12  Overcast   Hot   Normal  False      Yes
# 13     Sunny  Mild     High   True       No

# %%
data[data['OUTLOOK']=='Rainy']
# Out:
#    OUTLOOK  Temp Humidity  Windy PlayGolf
# 0    Rainy   Hot     High  False       No
# 1    Rainy   Hot     High   True       No
# 7    Rainy  Mild   Normal  False      Yes
# 8    Rainy  Cool   Normal  False      Yes
# 10   Rainy  Mild   Normal   True      Yes

# %%
list(data.head(0))
# Out:
# ['OUTLOOK', 'Temp', 'Humidity', 'Windy', 'PlayGolf']

# %%
for col in list(data.head(0)):
    elements=list(data[col])
    uElement=set(elements)
    print('\n')
    print(elements)
    print(uElement)
    
    print('\n')
    for e in uElement:
        df=data[data[col]==e]
        
        print('\n')
        print(df)
        print('\n')
# Out:
# ['Rainy', 'Rainy', 'Overcast', 'Sunny', 'Sunny', 'Sunny', 'Overcast', 'Rainy', 'Rainy', 'Sunny', 'Rainy', 'Overcast', 'Overcast', 'Sunny']
# {'Overcast', 'Sunny', 'Rainy'}
#
#
#
#
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 2   Overcast   Hot     High  False      Yes
# 6   Overcast  Cool     High   True      Yes
# 11  Overcast  Mild     High   True      Yes
# 12  Overcast   Hot   Normal  False      Yes
#
#
#
#
#    OUTLOOK  Temp Humidity  Windy PlayGolf
# 3    Sunny  Mild     High  False      Yes
# 4    Sunny  Cool   Normal  False      Yes
# 5    Sunny  Cool   Normal   True       No
# 9    Sunny  Mild   Normal  False      Yes
# 13   Sunny  Mild     High   True       No
#
#
#
#
#    OUTLOOK  Temp Humidity  Windy PlayGolf
# 0    Rainy   Hot     High  False       No
# 1    Rainy   Hot     High   True       No
# 7    Rainy  Mild   Normal  False      Yes
# 8    Rainy  Cool   Normal  False      Yes
# 10   Rainy  Mild   Normal   True      Yes
#
#
#
#
# ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool', 'Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild']
# {'Cool', 'Mild', 'Hot'}
#
#
#
#
#     OUTLOOK  Temp Humidity  Windy PlayGolf
# 4     Sunny  Cool   Normal  False      Yes
# 5     Sunny  Cool   Normal   True       No
# 6  Overcast  Cool     High   True      Yes
# 8     Rainy  Cool   Normal  False      Yes
#
#
#
#
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 3      Sunny  Mild     High  False      Yes
# 7      Rainy  Mild   Normal  False      Yes
# 9      Sunny  Mild   Normal  False      Yes
# 10     Rainy  Mild   Normal   True      Yes
# 11  Overcast  Mild     High   True      Yes
# 13     Sunny  Mild     High   True       No
#
#
#
#
#      OUTLOOK Temp Humidity  Windy PlayGolf
# 0      Rainy  Hot     High  False       No
# 1      Rainy  Hot     High   True       No
# 2   Overcast  Hot     High  False      Yes
# 12  Overcast  Hot   Normal  False      Yes
#
#
#
#
# ['High', 'High', 'High', 'High', 'Normal', 'Normal', 'High', 'Normal', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'High']
# {'High', 'Normal'}
#
#
#
#
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 0      Rainy   Hot     High  False       No
# 1      Rainy   Hot     High   True       No
# 2   Overcast   Hot     High  False      Yes
# 3      Sunny  Mild     High  False      Yes
# 6   Overcast  Cool     High   True      Yes
# 11  Overcast  Mild     High   True      Yes
# 13     Sunny  Mild     High   True       No
#
#
#
#
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 4      Sunny  Cool   Normal  False      Yes
# 5      Sunny  Cool   Normal   True       No
# 7      Rainy  Mild   Normal  False      Yes
# 8      Rainy  Cool   Normal  False      Yes
# 9      Sunny  Mild   Normal  False      Yes
# 10     Rainy  Mild   Normal   True      Yes
# 12  Overcast   Hot   Normal  False      Yes
#
#
#
#
# [False, True, False, False, False, True, True, False, False, False, True, True, False, True]
# {False, True}
#
#
#
#
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 0      Rainy   Hot     High  False       No
# 2   Overcast   Hot     High  False      Yes
# 3      Sunny  Mild     High  False      Yes
# 4      Sunny  Cool   Normal  False      Yes
# 7      Rainy  Mild   Normal  False      Yes
# 8      Rainy  Cool   Normal  False      Yes
# 9      Sunny  Mild   Normal  False      Yes
# 12  Overcast   Hot   Normal  False      Yes
#
#
#
#
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 1      Rainy   Hot     High   True       No
# 5      Sunny  Cool   Normal   True       No
# 6   Overcast  Cool     High   True      Yes
# 10     Rainy  Mild   Normal   True      Yes
# 11  Overcast  Mild     High   True      Yes
# 13     Sunny  Mild     High   True       No
#
#
#
#
# ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# {'Yes', 'No'}
#
#
#
#
#      OUTLOOK  Temp Humidity  Windy PlayGolf
# 2   Overcast   Hot     High  False      Yes
# 3      Sunny  Mild     High  False      Yes
# 4      Sunny  Cool   Normal  False      Yes
# 6   Overcast  Cool     High   True      Yes
# 7      Rainy  Mild   Normal  False      Yes
# 8      Rainy  Cool   Normal  False      Yes
# 9      Sunny  Mild   Normal  False      Yes
# 10     Rainy  Mild   Normal   True      Yes
# 11  Overcast  Mild     High   True      Yes
# 12  Overcast   Hot   Normal  False      Yes
#
#
#
#
#    OUTLOOK  Temp Humidity  Windy PlayGolf
# 0    Rainy   Hot     High  False       No
# 1    Rainy   Hot     High   True       No
# 5    Sunny  Cool   Normal   True       No
# 13   Sunny  Mild     High   True       No
