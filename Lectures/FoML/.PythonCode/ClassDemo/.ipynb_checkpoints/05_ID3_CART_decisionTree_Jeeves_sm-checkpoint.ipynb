# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib as mpl
import matplotlib.pyplot as plt
import os,glob,shutil,gzip

# %%
print(os.getcwd())
file="Jeeves_sm.xlsx"
data=pd.read_excel(file)
data
# Out:
# /home/prateek/Documents/GITHUB/CAS-CS/cas-cs.github.io/lectures/FoML/.PythonCode/ClassDemo
#    Temp Humidity  Windy PlayGolf
# 0   Hot     High   True      Yes
# 1   Hot     High  False      Yes
# 2  Mild   Normal  False      Yes
# 3  Mild   Normal   True       No
# 4  Cool   Normal  False       No
# 5  Cool   Normal   True       No

# %%
list(data.head(0))
# Out:
# ['Temp', 'Humidity', 'Windy', 'PlayGolf']

# %%
class Entropy:
    def __init__(self,df):
        self.df=df
        self.H=self.EntropyCalc()
    
    def EntropyCalc(self):
        df=self.df
        self.S=list(df.iloc[:, -1].values)
        self.set=list(set(self.S))
        p=[]
        count=[]
        for i,val in enumerate(self.set):
            count.append(self.S.count(val))
            p.append(self.S.count(val)/len(self.S))
        self.count=count
        self.P=np.array(p)
        self.H=np.sum(-1*self.P*np.log2(self.P))
        return self.H

    def __repr__(self):
        print("Input Data Frame")
        print(f"{self.df}\n")

        print(f"There are {len(self.S)} elements in sample space")
        print(f"Sample space: \n{self.S}")
        print(f"Unique values:\t{self.set}")
        print(f"Count of Unique values:\t {self.count}")
        print(f"Probability:\t {self.P}")
        print(f"\nEntropy={self.H}")
        return ''

print(Entropy(data))
main=Entropy(data)
H=main.H
H
# Out:
# Input Data Frame
#    Temp Humidity  Windy PlayGolf
# 0   Hot     High   True      Yes
# 1   Hot     High  False      Yes
# 2  Mild   Normal  False      Yes
# 3  Mild   Normal   True       No
# 4  Cool   Normal  False       No
# 5  Cool   Normal   True       No
#
# There are 6 elements in sample space
# Sample space:
# ['Yes', 'Yes', 'Yes', 'No', 'No', 'No']
# Unique values:	['No', 'Yes']
# Count of Unique values:	 [3, 3]
# Probability:	 [0.5 0.5]
#
# Entropy=1.0
# 1.0

# %%
def Prob(S,event):
    # print(S,event)
    S=list(S)
    event=event

    # print(S,event)
    p=[]
    p.append(S.count(event)/len(S))
    # print(p)
    return p

# S=list(data["OUTLOOK"].values)
# Prob(S,'Sunny')

# %%
Hmain=Entropy(data).H
InformationGain=[]
print(f"Entropy of Complete data set i {Hmain}")
S=list(data.head(0))
for i,col in enumerate(S):
    # print(i,len(list(data.head(0)))-1)
    if i==len(list(data.head(0)))-1:
        break
    elements=list(data[col])
    uElement=set(elements)
    print('\n\n\n=========================')
    print(f"Testing for {col}")
    print('=========================\n')
    print(f"Entries are: {elements}")
    print(f"Unique entries are: {uElement}")
    
    print('\n')
    Imat=[]
    for e in uElement:
        
        print('\n-------------------------------------')
        print(f"Checking for {col} == {e}")
        print('-------------------------------------\n')
        df=data[data[col]==e]
        P=Prob(data[col],e)[0]
        H=Entropy(df).H
        I=P*H
        Imat.append(I)
        print(f"Probability of {col} == {e} is {P}")
        df=df.drop(col,axis=1)
        print(f"Entropy of {col} == {e} is {H}")
        print(f"Information Gain of {col} when {e} is {I}")
        
        
        print('\n')
        print(df)
        print('\n')

    IG=Hmain-np.sum(Imat)
    InformationGain.append(IG)
    print("\n\n\n++++++++++++++++++++++++++++++++++")
    print(f'Information gain of {col} with is {IG}')
    print("++++++++++++++++++++++++++++++++++\n\n")

print("\n\n\n********************************************")
print(f'Information gain MATRIX {S[0:-2]} with is {InformationGain}')
print("********************************************\n")



print("\n\n\n CONCLUSION\n\n")
ParentNode=S[np.argmax(InformationGain)]
print(f"ParentNode is {ParentNode}")
ChildNode=list(set(data[ParentNode].values))
print(f"Child Nodes are {ChildNode}")
# Out:
# Entropy of Complete data set i 1.0
#
#
#
# =========================
# Testing for Temp
# =========================
#
# Entries are: ['Hot', 'Hot', 'Mild', 'Mild', 'Cool', 'Cool']
# Unique entries are: {'Cool', 'Mild', 'Hot'}
#
#
#
# -------------------------------------
# Checking for Temp == Cool
# -------------------------------------
#
# Probability of Temp == Cool is 0.3333333333333333
# Entropy of Temp == Cool is 0.0
# Information Gain of Temp when Cool is 0.0
#
#
#   Humidity  Windy PlayGolf
# 4   Normal  False       No
# 5   Normal   True       No
#
#
#
# -------------------------------------
# Checking for Temp == Mild
# -------------------------------------
#
# Probability of Temp == Mild is 0.3333333333333333
# Entropy of Temp == Mild is 1.0
# Information Gain of Temp when Mild is 0.3333333333333333
#
#
#   Humidity  Windy PlayGolf
# 2   Normal  False      Yes
# 3   Normal   True       No
#
#
#
# -------------------------------------
# Checking for Temp == Hot
# -------------------------------------
#
# Probability of Temp == Hot is 0.3333333333333333
# Entropy of Temp == Hot is 0.0
# Information Gain of Temp when Hot is 0.0
#
#
#   Humidity  Windy PlayGolf
# 0     High   True      Yes
# 1     High  False      Yes
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Temp with is 0.6666666666666667
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# =========================
# Testing for Humidity
# =========================
#
# Entries are: ['High', 'High', 'Normal', 'Normal', 'Normal', 'Normal']
# Unique entries are: {'Normal', 'High'}
#
#
#
# -------------------------------------
# Checking for Humidity == Normal
# -------------------------------------
#
# Probability of Humidity == Normal is 0.6666666666666666
# Entropy of Humidity == Normal is 0.8112781244591328
# Information Gain of Humidity when Normal is 0.5408520829727552
#
#
#    Temp  Windy PlayGolf
# 2  Mild  False      Yes
# 3  Mild   True       No
# 4  Cool  False       No
# 5  Cool   True       No
#
#
#
# -------------------------------------
# Checking for Humidity == High
# -------------------------------------
#
# Probability of Humidity == High is 0.3333333333333333
# Entropy of Humidity == High is 0.0
# Information Gain of Humidity when High is 0.0
#
#
#   Temp  Windy PlayGolf
# 0  Hot   True      Yes
# 1  Hot  False      Yes
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Humidity with is 0.4591479170272448
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# =========================
# Testing for Windy
# =========================
#
# Entries are: [True, False, False, True, False, True]
# Unique entries are: {False, True}
#
#
#
# -------------------------------------
# Checking for Windy == False
# -------------------------------------
#
# Probability of Windy == False is 0.5
# Entropy of Windy == False is 0.9182958340544896
# Information Gain of Windy when False is 0.4591479170272448
#
#
#    Temp Humidity PlayGolf
# 1   Hot     High      Yes
# 2  Mild   Normal      Yes
# 4  Cool   Normal       No
#
#
#
# -------------------------------------
# Checking for Windy == True
# -------------------------------------
#
# Probability of Windy == True is 0.5
# Entropy of Windy == True is 0.9182958340544896
# Information Gain of Windy when True is 0.4591479170272448
#
#
#    Temp Humidity PlayGolf
# 0   Hot     High      Yes
# 3  Mild   Normal       No
# 5  Cool   Normal       No
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Windy with is 0.08170416594551044
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# ********************************************
# Information gain MATRIX ['Temp', 'Humidity'] with is [0.6666666666666667, 0.4591479170272448, 0.08170416594551044]
# ********************************************
#
#
#
#
#  CONCLUSION
#
#
# ParentNode is Temp
# Child Nodes are ['Cool', 'Mild', 'Hot']

# %%
list(set(data[ParentNode].values))
# Out:
# ['Cool', 'Mild', 'Hot']

# %%
def tree(data):
    Hmain=Entropy(data).H
    InformationGain=[]
    print(f"Entropy of Complete data set i {Hmain}")
    S=list(data.head(0))
    for i,col in enumerate(S):
        # print(i,len(list(data.head(0)))-1)
        if i==len(list(data.head(0)))-1:
            break
        elements=list(data[col])
        uElement=set(elements)
        print('\n\n\n=========================')
        print(f"Testing for {col}")
        print('=========================\n')
        print(f"Entries are: {elements}")
        print(f"Unique entries are: {uElement}")

        print('\n')
        Imat=[]
        for e in uElement:

            print('\n-------------------------------------')
            print(f"Checking for {col} == {e}")
            print('-------------------------------------\n')
            df=data[data[col]==e]
            P=Prob(data[col],e)[0]
            H=Entropy(df).H
            I=P*H
            Imat.append(I)
            print(f"Probability of {col} == {e} is {P}")
            df=df.drop(col,axis=1)
            print(f"Entropy of {col} == {e} is {H}")
            print(f"Information Gain of {col} when {e} is {I}")


            print('\n')
            print(df)
            print('\n')

        IG=Hmain-np.sum(Imat)
        InformationGain.append(IG)
        print("\n\n\n++++++++++++++++++++++++++++++++++")
        print(f'Information gain of {col} with is {IG}')
        print("++++++++++++++++++++++++++++++++++\n\n")

    print("\n\n\n********************************************")
    print(f'Information gain MATRIX {S[0:-2]} with is {InformationGain}')
    print("********************************************\n")



    print("\n\n\n CONCLUSION\n\n")
    ParentNode=S[np.argmax(InformationGain)]
    print(f"ParentNode is {ParentNode}")
    ChildNode=list(set(data[ParentNode].values))
    print(f"Child Nodes are {ChildNode}")
    
    LeafNode=[]
    Decision=[]
    for child in ChildNode:
        childEntorpy=Entropy(data[data[ParentNode]==child]).H
        if childEntorpy==0:
            LeafNode.append(child)
            D=np.unique(data[data[ParentNode]==child].iloc[:,-1].values)[0]
            Decision.append(D)
            
        
    
    return ParentNode,ChildNode,LeafNode,Decision

P,C,L,D=tree(data)
print(P,C,L,D)
# Out:
# Entropy of Complete data set i 1.0
#
#
#
# =========================
# Testing for Temp
# =========================
#
# Entries are: ['Hot', 'Hot', 'Mild', 'Mild', 'Cool', 'Cool']
# Unique entries are: {'Cool', 'Mild', 'Hot'}
#
#
#
# -------------------------------------
# Checking for Temp == Cool
# -------------------------------------
#
# Probability of Temp == Cool is 0.3333333333333333
# Entropy of Temp == Cool is 0.0
# Information Gain of Temp when Cool is 0.0
#
#
#   Humidity  Windy PlayGolf
# 4   Normal  False       No
# 5   Normal   True       No
#
#
#
# -------------------------------------
# Checking for Temp == Mild
# -------------------------------------
#
# Probability of Temp == Mild is 0.3333333333333333
# Entropy of Temp == Mild is 1.0
# Information Gain of Temp when Mild is 0.3333333333333333
#
#
#   Humidity  Windy PlayGolf
# 2   Normal  False      Yes
# 3   Normal   True       No
#
#
#
# -------------------------------------
# Checking for Temp == Hot
# -------------------------------------
#
# Probability of Temp == Hot is 0.3333333333333333
# Entropy of Temp == Hot is 0.0
# Information Gain of Temp when Hot is 0.0
#
#
#   Humidity  Windy PlayGolf
# 0     High   True      Yes
# 1     High  False      Yes
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Temp with is 0.6666666666666667
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# =========================
# Testing for Humidity
# =========================
#
# Entries are: ['High', 'High', 'Normal', 'Normal', 'Normal', 'Normal']
# Unique entries are: {'Normal', 'High'}
#
#
#
# -------------------------------------
# Checking for Humidity == Normal
# -------------------------------------
#
# Probability of Humidity == Normal is 0.6666666666666666
# Entropy of Humidity == Normal is 0.8112781244591328
# Information Gain of Humidity when Normal is 0.5408520829727552
#
#
#    Temp  Windy PlayGolf
# 2  Mild  False      Yes
# 3  Mild   True       No
# 4  Cool  False       No
# 5  Cool   True       No
#
#
#
# -------------------------------------
# Checking for Humidity == High
# -------------------------------------
#
# Probability of Humidity == High is 0.3333333333333333
# Entropy of Humidity == High is 0.0
# Information Gain of Humidity when High is 0.0
#
#
#   Temp  Windy PlayGolf
# 0  Hot   True      Yes
# 1  Hot  False      Yes
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Humidity with is 0.4591479170272448
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# =========================
# Testing for Windy
# =========================
#
# Entries are: [True, False, False, True, False, True]
# Unique entries are: {False, True}
#
#
#
# -------------------------------------
# Checking for Windy == False
# -------------------------------------
#
# Probability of Windy == False is 0.5
# Entropy of Windy == False is 0.9182958340544896
# Information Gain of Windy when False is 0.4591479170272448
#
#
#    Temp Humidity PlayGolf
# 1   Hot     High      Yes
# 2  Mild   Normal      Yes
# 4  Cool   Normal       No
#
#
#
# -------------------------------------
# Checking for Windy == True
# -------------------------------------
#
# Probability of Windy == True is 0.5
# Entropy of Windy == True is 0.9182958340544896
# Information Gain of Windy when True is 0.4591479170272448
#
#
#    Temp Humidity PlayGolf
# 0   Hot     High      Yes
# 3  Mild   Normal       No
# 5  Cool   Normal       No
#
#
#
#
#
# ++++++++++++++++++++++++++++++++++
# Information gain of Windy with is 0.08170416594551044
# ++++++++++++++++++++++++++++++++++
#
#
#
#
#
# ********************************************
# Information gain MATRIX ['Temp', 'Humidity'] with is [0.6666666666666667, 0.4591479170272448, 0.08170416594551044]
# ********************************************
#
#
#
#
#  CONCLUSION
#
#
# ParentNode is Temp
# Child Nodes are ['Cool', 'Mild', 'Hot']
# Temp ['Cool', 'Mild', 'Hot'] ['Cool', 'Hot'] ['No', 'Yes']

# %%
class GenerateTree:
    def __init__(self,data):
        self.data=data
        Tree=self.SelectRootNode(data)
#         print(Tree)
    
    @staticmethod
    def Entropy(df):
        S=list(df.iloc[:, -1].values)
        Sunique=list(set(S))
        p=[]
        count=[]
        for i,val in enumerate(Sunique):
            count.append(S.count(val))
            p.append(S.count(val)/len(S))
        count=count
        P=np.array(p)
        H=np.sum(-1*P*np.log2(P))
        return H
    
    @staticmethod
    def Probability(S,event):
        S=list(S)
        p=[]
        p.append(S.count(event)/len(S))
        return p
    
    def SelectRootNode(self,data):
        Hmain=self.Entropy(data)
        InformationGain=[]
        S=list(data.head(0))
        for i,col in enumerate(S):
            if i==len(list(data.head(0))):
                break
            elements=list(data[col])
            uElement=set(elements)
            for e in uElement:
                df=data[data[col]==e]
                P=self.Probability(data[col],e)[0]
                H=self.Entropy(df)
                I=P*H
                Imat.append(I)

                df=df.drop(col,axis=1)


            IG=Hmain-np.sum(Imat)
#             print(IG)
            InformationGain.append(IG)
        ParentNode=S[np.argmax(InformationGain)]

        ChildNode=list(set(data[ParentNode].values))


        tree=dict(ParentNode=ParentNode,ChildNode=ChildNode)
    
    
        for child in ChildNode:
            subData=data[data[ParentNode]==child]
            decision=self.DecisionOrBranch(subData)
            tree[f"{ParentNode}={child}"]=decision
#             print(tree[child])
        self.tree=tree
        
        return tree
    
    def DecisionOrBranch(self,subData):
#         print(subData)
#         print("\n")
        childEntorpy=self.Entropy(subData)
#         print(childEntorpy)
        if childEntorpy==0:
            D=np.unique(subData.iloc[:,-1].values)[0]       
            return dict(Decision=D)
        else:
#             T=self.SelectRootNode(subData)
            return dict(TODO="estimate sub tree",data=subData)

      
T=GenerateTree(data)
# print(T.tree)
subdata=T.tree['Temp=Mild']['data']
subT=GenerateTree(subdata)
print(subT.tree)
# Out:
# {'ParentNode': 'Temp', 'ChildNode': ['Mild'], 'Temp=Mild': {'TODO': 'estimate sub tree', 'data':    Temp Humidity  Windy PlayGolf
# 2  Mild   Normal  False      Yes
# 3  Mild   Normal   True       No}}
