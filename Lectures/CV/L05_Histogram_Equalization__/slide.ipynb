# %% [markdown]
# # Histogram and Histogram Equalization

# %%
import os,shutil,gzip
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as mpimg

# %%
imagefilelist=glob("./*.jpg")
imagefilelist
# Out:
# ['./img.jpg']

# %% [markdown]
# ## Read Image and plot gray and individual color channels

# %%
# for i in imagefilelist:
#     print(i)
#     # plt.imshow(mpimg.imread(i))

img=mpimg.imread(imagefilelist[0])
# grayimg=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

R, G, B=cv2.split(img)
plt.figure()
fig,ax=plt.subplots(3,2)
ax[0,0].imshow(img)

ax[0,0].set_title("Orig")
ax[1,0].imshow(grayimg,cmap="gray")

ax[1,0].set_title("Gray")

ax[0,1].imshow(R,cmap="Reds",label="R")
ax[0,1].set_title("R")

ax[1,1].imshow(G,cmap="Greens",label="G")
ax[1,1].set_title("G")

ax[2,1].imshow(B,cmap="Blues",label="B")
ax[2,1].set_title("B")
fig.suptitle("Orignal image and individual channels")
# Out:
# ./img.jpg
# Text(0.5, 0.98, 'Orignal image and individual channels')

# %% [markdown]
# ## Histogram Equalize individual channels

# %%
Req=cv2.equalizeHist(R)
Geq=cv2.equalizeHist(G)
Beq=cv2.equalizeHist(B)

# %%
fig,ax=plt.subplots(3,2)

# %%
imgEq=cv2.merge((Req,Geq,Beq))

# %%
plt.imshow(imgEq)

# %%
x=np.zeros(255)

for pixel in Req.reshape(1,np.product(Req.size)):
    x[0,pixel]+=1

print(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [62], in <cell line: 3>()
#       1 x=np.zeros(255)
#       3 for pixel in Req.reshape(1,np.product(Req.size)):
# ----> 4     x[0,pixel]+=1
#       6 print(x)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
Req.size
# Out:
# 921600
